# %%
import pandas as pd
from rdkit import Chem

# %%
wb97xd3_df = pd.read_csv('tests/data/reaction/wb97xd3.csv')
ccsdtf12_dz_df = pd.read_csv('tests/data/reaction/ccsdtf12_dz.csv')
ccsdtf12_tz_df = pd.read_csv('tests/data/reaction/ccsdtf12_tz.csv')

# %%
# print the length of each df
print(len(wb97xd3_df))
print(len(ccsdtf12_dz_df))
print(len(ccsdtf12_tz_df))
# Out:
# 11926
# 11926
# 15

# %%
list(wb97xd3_df.columns)
# Out:
# ['idx', 'rsmi', 'psmi', 'rinchi', 'pinchi', 'dE0', 'dHrxn298', 'rmg_family']

# %%
# drop idx column from all dfs
wb97xd3_df = wb97xd3_df.drop(columns=['idx'])
ccsdtf12_dz_df = ccsdtf12_dz_df.drop(columns=['idx'])
ccsdtf12_tz_df = ccsdtf12_tz_df.drop(columns=['idx'])

# %%
# add a suffix of the df name to the 'dE0' and 'dHrxn298' column names in all dfs
wb97xd3_df = wb97xd3_df.rename(columns={'dE0': 'dE0_wb97xd3', 'dHrxn298': 'dHrxn298_wb97xd3'})
ccsdtf12_dz_df = ccsdtf12_dz_df.rename(columns={'dE0': 'dE0_ccsdtf12_dz', 'dHrxn298': 'dHrxn298_ccsdtf12_dz'})
ccsdtf12_tz_df = ccsdtf12_tz_df.rename(columns={'dE0': 'dE0_ccsdtf12_tz', 'dHrxn298': 'dHrxn298_ccsdtf12_tz'})

# %%
# merge all 4 dataframes on the shared columns
merged_df = pd.merge(wb97xd3_df, ccsdtf12_dz_df, on=['rsmi', 'psmi', 'rinchi', 'pinchi', 'rmg_family'], how='outer')
merged_df = pd.merge(merged_df, ccsdtf12_tz_df, on=['rsmi', 'psmi', 'rinchi', 'pinchi', 'rmg_family'], how='outer')
merged_df
# Out:
#                                                     rsmi
# 0      [C:1]([c:2]1[n:3][o:4][n:5][n:6]1)([H:7])([H:8...  \
# 1      [C:1]([c:2]1[n:3][o:4][n:5][n:6]1)([H:7])([H:8...
# 2      [C:1]([O:2][C:3]([C:4]([O:5][H:13])([H:11])[H:...
# 3      [C:1]([O:2][C:3]([C:4]([O:5][H:13])([H:11])[H:...
# 4      [C:1]([O:2][C:3]([C:4]([O:5][H:13])([H:11])[H:...
# ...                                                  ...
# 11921  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...
# 11922  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...
# 11923  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...
# 11924  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...
# 11925  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...
#
#                                                     psmi
# 0      [C:1]([C:2]([N:3]=[O:4])=[N+:6]=[N-:5])([H:7])...  \
# 1      [C:1]([N:3]=[C:2]=[N:6][N:5]=[O:4])([H:7])([H:...
# 2      [C:1]1([H:6])([H:7])[O:2][C:3]([H:9])([H:10])[...
# 3      [C:1]([O:2][H:13])([H:6])([H:7])[H:8].[C:3]1([...
# 4      [C:1]([O:2][H:13])([H:6])([H:7])[H:8].[C:3]([C...
# ...                                                  ...
# 11921  [C:1]([C:2][C:4]([O:5][C:6](=[O:7])[H:15])([H:...
# 11922  [C:1]([C@@:2]1([H:11])[O:3][C@:6]([O:7][H:12])...
# 11923  [C:1]([C@@:2]([O:3][H:12])([C:4](=[O:5])[H:14]...
# 11924  [C:1](=[C:2]([C:4]([O:5][C:6](=[O:7])[H:15])([...
# 11925  [C:1]([C:2](=[O:3])[C:4]([O:5][C:6]([O:7][H:12...
#
#                                                   rinchi
# 0                   InChI=1S/C2H3N3O/c1-2-3-5-6-4-2/h1H3  \
# 1                   InChI=1S/C2H3N3O/c1-2-3-5-6-4-2/h1H3
# 2               InChI=1S/C3H8O2/c1-5-3-2-4/h4H,2-3H2,1H3
# 3               InChI=1S/C3H8O2/c1-5-3-2-4/h4H,2-3H2,1H3
# 4               InChI=1S/C3H8O2/c1-5-3-2-4/h4H,2-3H2,1H3
# ...                                                  ...
# 11921  InChI=1S/C4H8O3/c1-4(6)2-7-3-5/h3-4,6H,2H2,1H3...
# 11922  InChI=1S/C4H8O3/c1-4(6)2-7-3-5/h3-4,6H,2H2,1H3...
# 11923  InChI=1S/C4H8O3/c1-4(6)2-7-3-5/h3-4,6H,2H2,1H3...
# 11924  InChI=1S/C4H8O3/c1-4(6)2-7-3-5/h3-4,6H,2H2,1H3...
# 11925  InChI=1S/C4H8O3/c1-4(6)2-7-3-5/h3-4,6H,2H2,1H3...
#
#                                                   pinchi  dE0_wb97xd3
# 0                     InChI=1S/C2H3N3O/c1-2(4-3)5-6/h1H3     48.73925  \
# 1                     InChI=1S/C2H3N3O/c1-3-2-4-5-6/h1H3     74.31711
# 2              InChI=1S/C3H6O.H2O/c1-2-4-3-1;/h1-3H2;1H2    102.81328
# 3         InChI=1S/C2H4O.CH4O/c1-2-3-1;1-2/h1-2H2;2H,1H3     76.92773
# 4          InChI=1S/C2H4O.CH4O/c1-2-3;1-2/h2H,1H3;2H,1H3     72.31295
# ...                                                  ...          ...
# 11921  InChI=1S/C4H6O2.H2O/c1-2-3-6-4-5;/h4H,3H2,1H3;1H2     76.63047
# 11922  InChI=1S/C4H8O3/c1-3-2-6-4(5)7-3/h3-5H,2H2,1H3...     43.81820
# 11923  InChI=1S/C3H6O2.CH2O/c1-3(5)2-4;1-2/h2-3,5H,1H...     73.72767
# 11924  InChI=1S/C4H6O2.H2O/c1-2-3-6-4-5;/h2,4H,1,3H2;1H2     66.77095
# 11925       InChI=1S/C4H8O3/c1-4(6)2-7-3-5/h5H,2-3H2,1H3     52.49260
#
#        dHrxn298_wb97xd3         rmg_family  dE0_ccsdtf12_dz
# 0              21.40228                NaN         48.61085  \
# 1              21.57450                NaN         74.02980
# 2              13.09638                NaN         97.42200
# 3              27.94548                NaN         75.25375
# 4               1.38990                NaN         72.16356
# ...                 ...                ...              ...
# 11921          81.75287                NaN         75.56813
# 11922           6.42893                NaN         42.41621
# 11923          31.87166                NaN         72.75039
# 11924          16.40895  1,3_Insertion_ROR         65.83112
# 11925          15.24899                NaN         52.57819
#
#        dHrxn298_ccsdtf12_dz  dE0_ccsdtf12_tz  dHrxn298_ccsdtf12_tz
# 0                  26.77621              NaN                   NaN
# 1                  28.79099              NaN                   NaN
# 2                  12.60220              NaN                   NaN
# 3                  28.98589              NaN                   NaN
# 4                   1.41779              NaN                   NaN
# ...                     ...              ...                   ...
# 11921              79.63518              NaN                   NaN
# 11922               5.79695              NaN                   NaN
# 11923              30.54744              NaN                   NaN
# 11924              14.48350              NaN                   NaN
# 11925              15.06159              NaN                   NaN
#
# [11926 rows x 11 columns]

# %%
merged_df.count()
# Out:
# rsmi                    11926
# psmi                    11926
# rinchi                  11926
# pinchi                  11926
# dE0_wb97xd3             11926
# dHrxn298_wb97xd3        11926
# rmg_family               1481
# dE0_ccsdtf12_dz         11926
# dHrxn298_ccsdtf12_dz    11926
# dE0_ccsdtf12_tz            15
# dHrxn298_ccsdtf12_tz       15
# dtype: int64

# %%
# show a sample of the duplicate rows that have the same idx but different rsmi
merged_df[merged_df.duplicated(subset=['rsmi', 'psmi', 'rinchi', 'pinchi', 'rmg_family'], keep=False)].sort_values('rsmi')
# Out:
# Empty DataFrame
# Columns: [rsmi, psmi, rinchi, pinchi, dE0_wb97xd3, dHrxn298_wb97xd3, rmg_family, dE0_ccsdtf12_dz, dHrxn298_ccsdtf12_dz, dE0_ccsdtf12_tz, dHrxn298_ccsdtf12_tz]
# Index: []

# %%
# combine the rsmi and psmi columns into a single column
merged_df['smiles'] = merged_df['rsmi']+'>>'+merged_df['psmi']

# %%
merged_df.columns
# Out:
# Index(['rsmi', 'psmi', 'rinchi', 'pinchi', 'dE0_wb97xd3', 'dHrxn298_wb97xd3',
#        'rmg_family', 'dE0_ccsdtf12_dz', 'dHrxn298_ccsdtf12_dz',
#        'dE0_ccsdtf12_tz', 'dHrxn298_ccsdtf12_tz', 'rxn_smiles', 'smiles'],
#       dtype='object')

# %%
merged_df[['smiles',
           'dE0_wb97xd3', 'dHrxn298_wb97xd3',
           'dE0_ccsdtf12_dz', 'dHrxn298_ccsdtf12_dz',
           'dE0_ccsdtf12_tz', 'dHrxn298_ccsdtf12_tz']]
# Out:
#                                                   smiles  dE0_wb97xd3
# 0      [C:1]([c:2]1[n:3][o:4][n:5][n:6]1)([H:7])([H:8...     48.73925  \
# 1      [C:1]([c:2]1[n:3][o:4][n:5][n:6]1)([H:7])([H:8...     74.31711
# 2      [C:1]([O:2][C:3]([C:4]([O:5][H:13])([H:11])[H:...    102.81328
# 3      [C:1]([O:2][C:3]([C:4]([O:5][H:13])([H:11])[H:...     76.92773
# 4      [C:1]([O:2][C:3]([C:4]([O:5][H:13])([H:11])[H:...     72.31295
# ...                                                  ...          ...
# 11921  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...     76.63047
# 11922  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...     43.81820
# 11923  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...     73.72767
# 11924  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...     66.77095
# 11925  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...     52.49260
#
#        dHrxn298_wb97xd3  dE0_ccsdtf12_dz  dHrxn298_ccsdtf12_dz
# 0              21.40228         48.61085              26.77621  \
# 1              21.57450         74.02980              28.79099
# 2              13.09638         97.42200              12.60220
# 3              27.94548         75.25375              28.98589
# 4               1.38990         72.16356               1.41779
# ...                 ...              ...                   ...
# 11921          81.75287         75.56813              79.63518
# 11922           6.42893         42.41621               5.79695
# 11923          31.87166         72.75039              30.54744
# 11924          16.40895         65.83112              14.48350
# 11925          15.24899         52.57819              15.06159
#
#        dE0_ccsdtf12_tz  dHrxn298_ccsdtf12_tz
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
# ...                ...                   ...
# 11921              NaN                   NaN
# 11922              NaN                   NaN
# 11923              NaN                   NaN
# 11924              NaN                   NaN
# 11925              NaN                   NaN
#
# [11926 rows x 7 columns]

# %%
merged_df[['smiles','dHrxn298_wb97xd3','dHrxn298_ccsdtf12_dz']]
# Out:
#                                                   smiles  dHrxn298_wb97xd3
# 0      [C:1]([c:2]1[n:3][o:4][n:5][n:6]1)([H:7])([H:8...          21.40228  \
# 1      [C:1]([c:2]1[n:3][o:4][n:5][n:6]1)([H:7])([H:8...          21.57450
# 2      [C:1]([O:2][C:3]([C:4]([O:5][H:13])([H:11])[H:...          13.09638
# 3      [C:1]([O:2][C:3]([C:4]([O:5][H:13])([H:11])[H:...          27.94548
# 4      [C:1]([O:2][C:3]([C:4]([O:5][H:13])([H:11])[H:...           1.38990
# ...                                                  ...               ...
# 11921  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...          81.75287
# 11922  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...           6.42893
# 11923  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...          31.87166
# 11924  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...          16.40895
# 11925  [C:1]([C@@:2]([O:3][H:12])([C:4]([O:5][C:6](=[...          15.24899
#
#        dHrxn298_ccsdtf12_dz
# 0                  26.77621
# 1                  28.79099
# 2                  12.60220
# 3                  28.98589
# 4                   1.41779
# ...                     ...
# 11921              79.63518
# 11922               5.79695
# 11923              30.54744
# 11924              14.48350
# 11925              15.06159
#
# [11926 rows x 3 columns]

# %%
merged_df[['smiles','dHrxn298_wb97xd3','dHrxn298_ccsdtf12_dz']].to_csv('tests/data/reaction/dHrxn298_wb97xd3_ccsdtf12.csv', index=False)
